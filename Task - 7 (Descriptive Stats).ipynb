# %%
import pandas as pd
import numpy as np
import statistics

# %%
df=pd.read_csv("data.csv")
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Mean

# %% [markdown]
# The Arithmetic Mean (generally known as "average") is a broadly used measure to describe a population using a single value.
# Arithmetic Mean is a measure which is used for numeric data and is a single value that represents the typical value in the given set of numbers.
# The arithmetic mean is the sum of all values in the data set divided by the total number of values in the data set.

# %% [markdown]
# $$ Arithmetic Mean= \frac {Sum of values in the dataset}{Number of values in the dataset} = \frac{1}{N} \sum_{i=1}^N x_i = \frac{x_1+x_2+x_3+....x_i}{n}$$

# %% [markdown]
# Depending on whether the data being analyzed is a sample or the population, the notation used to represent mean changes.
# The sample mean is represented as x and population mean as μ.

# %% [markdown]
# The arithmetic mean can be computed using the command mean(x) from statistics module in python as shown below:

# %%
monthly_income = df['Mthly_HH_Income']
print(statistics.mean(monthly_income))
# Out:
# 41558

# %%
#Alternative approach 1
average = np.mean(np.array(monthly_income))
print(average)
# Out:
# 41558.0

# %%
#Alternative approach 2
df["Mthly_HH_Income"].mean()
# Out:
# 41558.0

# %% [markdown]
# ## Median

# %% [markdown]
# Median is the value that lies at the centre of the data set when data is ordered. Median divides the data into equal halves when the data is sorted.
#
# Finding the median:
# 1. If there are an odd number of values, the median is the value at the centre that divides the data into equal halves
# $$ Median = \frac{(n+1)}{2}^{th} observation $$
# 2. If there are even number of values, the median is the average of the two middle values
# $$ Median = \frac{\frac{n}{2}^{th} + \frac{(n+1)}{2}^{th} observation }{2}$$

# %% [markdown]
# The presence of extreme values (unusually large/small values) in data affects the mean/average. Median is another measure of central tendency, is generally the preferred value in such cases.

# %% [markdown]
# The arithmetic mean can be computed using the command mean(x) from statistics module in python as shown below:

# %%
print(statistics.median(monthly_income))
# Out:
# 35000.0

# %%
#Alternative Approach 1
print(np.median(np.array(monthly_income)))
# Out:
# 35000.0

# %%
#Alternative Approach 2
df["Mthly_HH_Income"].median()
# Out:
# 35000.0

# %% [markdown]
# ## Mode

# %% [markdown]
# Data that is most frequently occurring in a data set is called Mode.

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# It is possible for a dataset to have multiple modes. Datasets containing one value for mode are called unimodal, two modes are called bimodal, and more than two are called multimodal.
# The mode is mostly used when the data being analyzed is non-numeric but its not compulsory.

# %% [markdown]
# The mode can be calculated in python using stats.mode() function from scipy library in python.

# %%
from scipy import stats
print(stats.mode(df['No_of_Fly_Members']))
# Out:
# ModeResult(mode=array([4], dtype=int64), count=array([15]))

# %% [markdown]
# ![difference-between-mode-mean-median-260nw-1969308643.jpg](attachment:difference-between-mode-mean-median-260nw-1969308643.jpg)

# %% [markdown]
# ## Variance

# %% [markdown]
# Variance describes the deviation of data from each other and from the mean. It is expressed in square units.
#
# Variance for a population of size N can be calculated by using the following formula:

# %% [markdown]
# $$Var(X)=\frac{\sum{(x-\mu)}^2}{n}$$

# %% [markdown]
# Steps to calculate Variance :
#
# 1. First Calculate the Mean.
# 2. Subtract each observation with the mean, the resultant is called deviation.
# 3. Square the deviation.
# 4. Find the sum of all the squared deviations.
# 5. Take the value from step 4 and divide with the total no of observations.

# %% [markdown]
# Population Variance	$\sigma^2=\frac{\sum{(x-\mu)}^2}{n}$
# Sample Variance
# $S^2=\frac{\sum{(x-\bar{X})}^2}{n-1}$

# %%
mean=sum(df["No_of_Fly_Members"])/len(df["No_of_Fly_Members"])
dev=[(i-mean)**2 for i in df["No_of_Fly_Members"]]
var= sum(dev)/(len(df["No_of_Fly_Members"])-1)
print(var)
# Out:
# 2.302448979591837

# %% [markdown]
# The variance can be computed in python using the following python code:

# %%
import statistics as st
print(st.variance(df["No_of_Fly_Members"])) #Sample variance of data.
print(st.pvariance(df["No_of_Fly_Members"])) #Population variance of data.
# Out:
# 2.3024489795918366
# 2.2564

# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# The actual variation of the data from the mean is represented by Standard Deviation and it is represented in the same unit as that of data.

# %% [markdown]
# Standard Deviation is the square root of the variance which can be calculated using the formula:
#
# $$SD=\sqrt\frac{\sum{(x-\mu)}^2}{n}$$

# %% [markdown]
# The dispersion of data can be expressed by either the standard deviation or the variance.
#
# From representing the population, the standard deviation is represented by σ and for the sample, the standard deviation is represented by s.

# %% [markdown]
# The standard deviation can be computed using the command dev(x) from statistics package in python as shown below:

# %%
import statistics as st
print("Sample Standard Deviation ",st.stdev(df["No_of_Fly_Members"])) # Sample standard deviation of the data.
print("Population Standard Deviation ",st.pstdev(df["No_of_Fly_Members"])) #Population standard deviation of the data.
# Out:
# Sample Standard Deviation  1.5173822786601392
# Population Standard Deviation  1.502131818450032

# %%
#Alternative Approach 1
df["No_of_Fly_Members"].std()
# Out:
# 1.5173822786601394

# %% [markdown]
# Points to note :
# 1. Low standard deviation indicates the values are close to their mean.
# 2. High standard deviation indicates the data points are wide spread across the mean.

# %% [markdown]
# ## Correlation

# %% [markdown]
# Correlation is a measure of the strength and direction of the linear association between two quantitative variables.Correlation is normalized covariance and is generally obtained by dividing the covariance by the product of standard deviation of the variables.
#
# $$cor(X,Y)=\frac{cov(X,Y)}{s_xs_y}$$

# %% [markdown]
# $$cov(X,Y) = E[(X-\mu_x)(Y-\mu_y)] = (E[XY]-\mu_x\mu_y)$$
#
# where
# $$\mu_x = E[X], \mu_y = E[Y]$$ are the respective means

# %% [markdown]
# Owing to normalization, correlation always lies in the range of [-1, +1].
# The correlation of a sample is represented using r and that of a population is represented using ρ (rho).
#
# The sign of correlation indicates the direction of the association, as expressed below
# 1. positive association: r or ρ > 0
# 2. negative association: r or ρ < 0
# 3. no linear association: r or ρ ≈ 0
#
# The closer r (or ρ) is to ±1, the stronger the linear association.
# If the correlation is closer to 0, then the variables might be statistically independent.

# %% [markdown]
# Correlation is computed using corr method of the pandas library.

# %%
df.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %% [markdown]
# ## Normal Distribution

# %% [markdown]
# It is a bell-shaped frequency distribution curve. It follows an important statistical data distribution pattern occurring in many natural phenomena such as height, weight, blood pressure, etc.
#
# Example:
# A teacher analyzing the average marks of 10th class students from a school. The plot will take a bell curve if marks are normally distributed.
# ![Normal-Distribution.jpg](attachment:Normal-Distribution.jpg)

# %% [markdown]
# In probability theory, the Normal Distribution a.k.a. Gaussian Distribution is symmetrical with a single central peak(unimodal) at the mean.
#
# When normally distributed random variables are plotted with random variable values on the horizontal axis (x-axis) and their respective probabilities on the vertical axis (y-axis), a bell-shaped curve known as a normal curve is created, falling evenly on either side of the mean.
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ### Features of Normal Distribution

# %% [markdown]
# Following are properties of X (Random Variable) which is following the normal distribution:
#
# 1. The bell-shaped  frequency distribution curve
# 2. 1 is the total area under the normal curve
# 3. 0 is the probability of X (normal random variable) being equal to particular value.
# 4. Mean, median and mode of the distribution are at the center
# 5. The curve is x-axis asymptote, i.e. two normal distribution tails never touch the x-axis and extend indefinitely
# 6. The skewness for Normal distribution is 0.
# 7. The kurtosis for Normal distribution is 3.
# 8. Exactly half of the values are to the left of center and exactly half the values are to the right.
# 9. The curve is symmetric at the center (i.e. around the mean, μ).
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ### Empirical rule for the normal distribution

# %% [markdown]
# ![standard-normal-distribution-with-probabilities.png](attachment:standard-normal-distribution-with-probabilities.png)
# 1. 68% of data lies in the one standard deviation away from the mean.
# 2. 95% of data lies in the two standard deviation away from the mean.
# 3. 99.7% of data lies in the three standard deviation away from the mean.
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ## Positively Skewed & Negatively Skewed Normal Distribution

# %% [markdown]
# ### Skewness
# In probability theory and statistics, skewness is a measure of the asymmetry of the probability distribution of a random variable. The skewness value can be Positive, Zero, Negative.

# %% [markdown]
# $$\frac {\sum_{i}^N (X_i-\bar{X})^3}{(N-1)*\sigma^3}$$
#
# $X_i$ is each individual score;
# $\bar{X}$ is the population mean;
# σ is the population standard deviation and
# N is the population size.

# %% [markdown]
# ### Positive Skewness
# In statistics, a positively skewed (or right-skewed) distribution is a type of distribution in which most values are clustered around the left tail of the distribution while the right tail of the distribution is longer. In a positively skewed distribution, the mean can be found on the right from the distribution’s peak.

# %% [markdown]
# ### Negative Skewness
# In statistics, a negatively skewed (also known as left-skewed) distribution is a type of distribution in which more values are concentrated on the right side (tail) of the distribution graph while the left tail of the distribution graph is longer. In negatively skewed distributions is that the arithmetic mean is generally located on the left from the peak of the distribution.

# %% [markdown]
# ### Zero Skewness
# The skewness for a normal distribution is zero, and any symmetric data should have a skewness near zero.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ## Effect on Mean, Median and Mode due to Skewness

# %% [markdown]
# Unlike with normally distributed data where all measures of the central tendency (mean, median, and mode) equal each other, with positively skewed data, the measures are dispersed. The general relationship among the central tendency measures in a positively skewed distribution may be expressed using the following inequality:
#
# Mean  >  Median  >  Mode

# %% [markdown]
# Unlike normally distributed data where all measures of central tendency (mean, median, and mode) equal each other, with negatively skewed data, the measures are dispersed. The general relationship between the central tendency measures in a negatively skewed distribution may be expressed using the following inequality:
#
# Mode  >  Median  > Mean

# %% [markdown]
# When the skewness is 0, it means it is a normal distribution and hence, mean = median = mode.

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ## QQ Plot

# %% [markdown]
# When the quantiles of two variables are plotted against each other, then the plot obtained is known as quantile – quantile plot or qqplot. This plot provides a summary of whether the distributions of two variables are similar or not with respect to the locations.

# %% [markdown]
# ### Interpretations
# 1. All point of quantiles lie on or close to straight line at an angle of 45 degree from x – axis. It indicates that two samples have similar distributions.
# ![Capture1.PNG](attachment:Capture1.PNG)
# And in practice it is always not possible to get such a 100 percent clear straight line but the plot looks like below. Here the points are lying nearly on the straight line.
# ![Capture2.PNG](attachment:Capture2.PNG)
# 2. The y – quantiles are lower than the x – quantiles. It indicates y values have a tendency to be lower than x values.
# ![Capture3.PNG](attachment:Capture3.PNG)
# And in practice it is not always possible to get 100 percent as shown above but the plot looks as shown below. Here you can see that most of the points are lying below the line and few points are above the line. Hence we can say that the distributions are not the same.
# ![Capture4.PNG](attachment:Capture4.PNG)
# 3. The x – quantiles are lower than the y – quantiles. It indicates x values have a tendency to be lower than the y values.
# ![Capture5.PNG](attachment:Capture5.PNG)
# 4. Indicates that there is a breakpoint up to which the y – quantiles are lower than the x – quantiles and after that point the y – quantiles are higher than the x – quantiles.
# ![Capture6.PNG](attachment:Capture6.PNG)

# %% [markdown]
# ### Implementation

# %%
import statsmodels.api as sm
import pylab as py
data_points = np.random.normal(0, 1, 100)

sm.qqplot(data_points, line ='45')
py.show()

# %% [markdown]
# ## Box Cox Transformation

# %% [markdown]
#  A Box cox transformation is defined as a way to transform non-normal dependent variables in our data to a normal shape through which we can run a lot more tests than we could have.
#
#  Mathematics behind Box-Cox Transformation:
#
# How can we convert our intuitive thinking into a mathematical transformation function? Logarithmic transformation is all we need. When a log transformation is applied to non-normal distribution, it tries to expand the differences between the smaller values because the slope for the logarithmic function is steeper for smaller values whereas the differences between the larger values can be reduced because, for large values, log distribution has a moderate slope.

# %% [markdown]
# Box-cox Transformation only cares about computing the value of \lambda  which varies from – 5 to 5. A value of \lambda  is said to be best if it is able to approximate the non-normal curve to a normal curve. The transformation equation is as follows:
# ![Capture7.PNG](attachment:Capture7.PNG)
# This function requires input to be positive.

# %% [markdown]
# ### Implementation
# SciPy’s stats package provides a function called boxcox for performing box-cox power transformation that takes in original non-normal data as input and returns fitted data along with the lambda value that was used to fit the non-normal distribution to normal distribution.

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# generate non-normal data (exponential)
original_data = np.random.exponential(size = 1000)

# transform training data & save lambda value
fitted_data, fitted_lambda = stats.boxcox(original_data)

# creating axes to draw plots
fig, ax = plt.subplots(1, 2)

# plotting the original data(non-normal) and
# fitted data (normal)
sns.distplot(original_data, hist = False, kde = True,
kde_kws = {'shade': True, 'linewidth': 2},
label = "Non-Normal", color ="green", ax = ax[0])

sns.distplot(fitted_data, hist = False, kde = True,
kde_kws = {'shade': True, 'linewidth': 2},
label = "Normal", color ="green", ax = ax[1])

# adding legends to the subplots
plt.legend(loc = "upper right")

# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)

print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# Lambda value used for Transformation: 0.2493230704843882

# %% [markdown]
# Box-cox does not guarantee normality because it never checks for the normality which is necessary to be foolproof that it has correctly transformed the non-normal distribution or not. It only checks for the smallest Standard deviation.
# Therefore, it is absolutely necessary to always check the transformed data for normality using a probability plot.

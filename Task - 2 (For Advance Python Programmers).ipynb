# %%
'''1. Given a valid (IPv4) IP address, return a defanged version of that IP address.
A defanged IP address replaces every period "." with "[.]".'''

string = input()
print(string.replace(".","[.]"))
# Out:
# 255.100.50.0
# 255[.]100[.]50[.]0

# %%
'''2. Given an array nums of integers, return how many of them contain an even number of digit'''
array = list(x for x in input().split(','))
count = 0
for number in array:
    if ((len(number) % 2) == 0):
        count = count + 1

print(count)
# Out:
# 555,901,482,1771
# 1

# %%
'''3. Given an array of integers nums, return the number of good pairs.
A pair (i, j) is called good if nums[i] == nums[j] and i < j.'''

array = list(int(x) for x in input().split(','))
count = 0
for i in range(0,len(array)):
    for j in range(0,len(array)):
        if i < j:
            if array[i]==array[j]:
                count = count + 1
                
print(count)
# Out:
# 1,2,3,1,1,3
# 4

# %%
'''4. Given the array nums, for each nums[i] find out how many numbers in the array are smaller than it. 
That is, for each nums[i] you have to count the number of valid j's such that j != i and nums[j] < nums[i].
Return the answer in an array.'''

array = list(int(x) for x in input().split(','))
result = []
for i in range(0,len(array)):
    count = 0
    for j in range(0,len(array)):
        if j!=i:
            if array[j] < array[i]:
                count = count + 1
    result.append(count)
print(result)
# Out:
# 8,1,2,2,3
# [4, 0, 1, 1, 3]

# %%
'''5. Given an integer number n, return the difference between the product of its digits and the sum of its digits.'''

number = input()
product = 1
add = 0
for i in number:
    product = product * int(i)
    add = add + int(i)
difference = product - add
print(difference)
# Out:
# 4421
# 21

# %%
'''6. Given an integer n and an integer start.
Define an array nums where nums[i] = start + 2*i (0-indexed) and n == nums.length.
Return the bitwise XOR of all elements of nums.'''

n = int(input())
start = int(input())
nums = []
for i in range(0,n):
    nums.append(start + (2*i))
xor_result = 0
for i in range(0,n):
    xor_result = xor_result ^ nums[i]

print(xor_result)
# Out:
# 4
# 3
# 8
